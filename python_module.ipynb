# %%
# How to Use Modules

import math

print(math.sqrt(25))
print(math.factorial(3))
# Out:
# 5.0
# 6

# %%
# Use the module in another file

import mymodule
mymodule.greet("alice")
print("Value of py:",mymodule.pi)
# Out:
# Hello,alice
# Value of py: 3.14159

# %%
# Python Datetime

import datetime 
now = datetime.datetime.now()
print("Current date and time:", now)
# Out:
# Current date and time: 2025-09-16 11:54:34.612816

# %%
# Python RegEx (Regular Expressions)
# Search for number in the text
import re
text = "my age is 20"
result = re.search(r"\d+",text)
if result:
    print("Number found:",result.group())
# Out:
# Number found: 20

# %%
# Raising an exception in Python

# age = -5
# if age <0:
#     raise ValueError("Age cannot be negative")

# %%
# 1. Division Calculator
# Task:
#  Write a program that asks the user for two numbers and prints their division result.
# Handle:
# ZeroDivisionError (if user enters 0 as the divisor)
# ValueError (if user enters non-numeric input)
# :memo: Hint: Use try…except around int() and division.

a_str = input("Enter the first number:")
b_str = input("Enter the second number")
try:
    divide = a_str/b_str
    print("Result of divition is",divide)
except ValueError:
    print("Invalid input. Please enter numeric values only.")
except ZeroDivisionError:
    print("Error: Cannot divide by zero. Please enter a non-zero divisor.")
# except Exception as e:
#             print(f"An unexpected error occurred: {e}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 12
#      10 b_str = input("Enter the second number")
#      11 try:
# ---> 12     divide = a_str/b_str
#      13     print("Result of divition is",divide)
#      14 except ValueError:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'
